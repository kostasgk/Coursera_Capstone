# %% [markdown]
# # Stores (bakeries , caffeterias , etc.)  in the center of Athens , Greece

# %% [markdown]
# The business problem we are going to describe is about what kind of stores someone cen find in the center of Athens Greece and using data from Foursquare API or other sources we will examine whether someone can invest on bying coffee stores, bakeries , restaurants , etc.

# %%
# !pip install folium
import numpy as np 

import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json 


from geopy.geocoders import Nominatim 

import requests # library to handle requests
from pandas.io.json import json_normalize

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
from folium import plugins
from folium.plugins import MarkerCluster

print('Libraries imported.')
# Out:
# ...
# Libraries imported.

# %%
import pandas as pd 
import requests
from bs4 import BeautifulSoup

url = 'https://www.weatherdatasource.com/GR-Attiki'#retrieve data foa Attiki region from weatherdatasource 
website_text = requests.get(url).text
soup = BeautifulSoup(website_text,'xml')
table_contents = []
divs = soup.find_all("ul", {"class": "list-group w-100 align-items-stretch"})
                     
for ultag in divs:
     for litag in ultag.find_all('li'):
            cell = {}
            cell['City']=litag.text
            cell['State']='Attiki'
            table_contents.append(cell)
#print(table_contents)
df_CityList=pd.DataFrame(table_contents).sort_values(by='City')
df_CityList
# Out:
#                   City   State
# 0             Acharnes  Attiki
# 1            Aianteion  Attiki
# 2              Aigaleo  Attiki
# 3               Aigina  Attiki
# 4               Alimos  Attiki
# 5           Amarousion  Attiki
# 6            Ampelakia  Attiki
# 7            Anavyssos  Attiki
# 8           Ano Liosia  Attiki
# 9               Anoixi  Attiki
# 10         Aspropirgos  Attiki
# 11              Athens  Attiki
# 12         Ayia Marina  Attiki
# 13      Ayia Paraskevi  Attiki
# 14        Ayia Varvara  Attiki
# 15      Ayios Stefanos  Attiki
# 16               Ekali  Attiki
# 17            Elefsina  Attiki
# 18           Ellinikon  Attiki
# 19            Erithrai  Attiki
# 20                Fili  Attiki
# 21             Galatas  Attiki
# 22           Galatsion  Attiki
# 23         Grammatikon  Attiki
# 24          Kaisariani  Attiki
# 25            Kalamaki  Attiki
# 26             Kalamos  Attiki
# 27           Kallithea  Attiki
# 28    Kalyvia Thorikou  Attiki
# ...

# %% [markdown]
# We retrieve data from www.weatherdatasource.com for the Attiki region , so we can see all the neighborhoods and suburbs belonging in this area

# %%
from geopy.geocoders import Nominatim
